# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
train_data_file  = '/content/drive/MyDrive/Inteligencia Artificial y Modelos/fase-2/Datos_BELKA/train.parquet'
test_input_file  = '/content/drive/MyDrive/Inteligencia Artificial y Modelos/fase-2/test_data_input.csv'
test_target_file = '/content/drive/MyDrive/Inteligencia Artificial y Modelos/fase-2/test_data_target.csv'
test_preds_file  = '/content/drive/MyDrive/Inteligencia Artificial y Modelos/fase-2/test_predictions.csv'
model_file       = '/content/drive/MyDrive/Inteligencia Artificial y Modelos/fase-2/model.pkl'

# %%
# Cargar el archivo y revisar sus dimensiones
Xts = pd.read_csv(test_input_file)
print(Xts.shape)  # Esto te dirá cuántas filas y columnas hay
# Out:
# (12000, 1027)

# %%
# !pip install loguru

# %%
  # !pip install rdkit-pypi

# %%
import sys
python = sys.executable

# %% [markdown]
# **Entrenamiento del modelo y guardarlo**

# %%
# !$python '/content/drive/MyDrive/Inteligencia Artificial y Modelos/fase-2/Scripts/train.py' --model_file "$model_file" --data_file "$train_data_file"  --overwrite_model
# Out:
# 2024-10-14 22:27:36.578 | INFO     | __main__:<module>:41 - overwriting existing model file /content/drive/MyDrive/Inteligencia Artificial y Modelos/fase-2/model.pkl
# 2024-10-14 22:27:36.579 | INFO     | __main__:<module>:46 - loading train data
# 2024-10-14 22:31:07.710 | INFO     | __main__:<module>:85 - fitting model
# 2024-10-14 22:31:45.260 | INFO     | __main__:<module>:92 - saving model to /content/drive/MyDrive/Inteligencia Artificial y Modelos/fase-2/model.pkl

# %% [markdown]
# **Realizar predicciones con el modelo guardado**

# %%
# !python  '/content/drive/MyDrive/Inteligencia Artificial y Modelos/fase-2/Scripts/predict.py' --model_file "$model_file" --input_file "$test_input_file"  --predictions_file "$test_preds_file"
# Out:
# 2024-10-14 22:15:40.961 | INFO     | __main__:<module>:39 - loading input data
# 2024-10-14 22:15:42.966 | INFO     | __main__:<module>:43 - loading model
# 2024-10-14 22:15:45.478 | INFO     | __main__:<module>:47 - making predictions
# 2024-10-14 22:15:46.141 | INFO     | __main__:<module>:50 - saving predictions to /content/drive/MyDrive/Inteligencia Artificial y Modelos/fase-2/test_predictions.csv

# %% [markdown]
# **load predictions and compare with target in test**

# %%
import pandas as pd
import numpy as np

preds   = pd.read_csv(test_preds_file).values
targets = pd.read_csv(test_target_file).values

acc = np.mean(preds==targets)
print (f"accuracy on test {acc:.3f}")
# Out:
# accuracy on test 0.894
